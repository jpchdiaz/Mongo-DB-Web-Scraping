# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_capitals_in_the_United_States"
# url = "https://cnn.com"

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                           0   \
#  0                                       State
#  1   Municipal (Within city proper boundaries)
#  2                                     Alabama
#  3                                      Alaska
#  4                                     Arizona
#  5                                    Arkansas
#  6                                  California
#  7                                    Colorado
#  8                                 Connecticut
#  9                                    Delaware
#  10                                    Florida
#  11                                    Georgia
#  12                                     Hawaii
#  13                                      Idaho
#  14                                   Illinois
#  15                                    Indiana
#  16                                       Iowa
#  17                                     Kansas
#  18                                   Kentucky
# ...

# %%
tabdf = tables[0]
# tabdf.head()
yo = list(tabdf.iloc[0])
yo
#how to turn the first row into header names?
# Out:
# ['State',
#  'Abr.',
#  'State-hood',
#  'Capital',
#  'Capital since',
#  'Area (mi²)',
#  'Population (2010)',
#  'Notes',
#  nan,
#  nan,
#  nan]
